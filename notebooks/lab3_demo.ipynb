# %% [markdown]
# # CSC4005 Lab 3 – UrbanSound8K with 1D-CNN
#
# Notebook này dùng để demo nhanh luồng xử lý. Khi nộp bài, sinh viên nên chạy bằng terminal để output được lưu đầy đủ trong `outputs/` và W&B.

# %% [markdown]
# ## 1. Kiểm tra môi trường
#
# Chạy cell sau để kiểm tra PyTorch và W&B.

# %%
import torch
print('torch:', torch.__version__)
print('cuda:', torch.cuda.is_available())
print('mps:', hasattr(torch.backends, 'mps') and torch.backends.mps.is_available())

# %% [markdown]
# ## 2. Lệnh train khuyến nghị
#
# Thay `/duong_dan/UrbanSound8K` bằng đường dẫn thật trên máy.

# %%
# !python -m src.train \
#   --config configs/baseline_mfcc_1dcnn.json \
#   --data_dir /duong_dan/UrbanSound8K

# %% [markdown]
# ## 3. Bài mở rộng raw waveform
#
# Raw waveform khó hơn và có thể chạy lâu hơn, chỉ dùng sau khi baseline MFCC chạy ổn.

# %%
# !python -m src.train \
#   --config configs/extension_raw_waveform.json \
#   --data_dir /duong_dan/UrbanSound8K
